# %%
import matplotlib.pyplot as plt
import torch

# %%
lunar_loss, lunar_train_reward, lunar_eval_reward = torch.load('saved_logs/actor_critic_6000.pkl')
cart_loss, cart_train_reward, cart_eval_reward = torch.load('saved_logs/ac_3layer.pkl')

# %%
plt.plot(lunar_train_reward)
plt.title("Train Reward for Lunar Landing")
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.savefig('lunar_train_reward.png')

# %%
plt.plot(cart_train_reward)
plt.title("Train Reward for Cart Pole")
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.savefig('cart_train_reward.png')
